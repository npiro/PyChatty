# %% [markdown]
# ### Load existing LDA model

# %%
import topic_modeling; reload(topic_modeling)
topic_modeling.verbose  = 'yes'

model = topic_modeling.load_LDA_model('/home/walter/Dropbox/S2DS - M&S/Data/LDAmodel__num_topics30__passes5__min_df5__max_df0.95__max_featuresNone__corpus_id05_fastTextConv.pickle')
#model = topic_modeling.load_LDA_model('/home/walter/Dropbox/S2DS - M&S/Data/LDAmodel__num_topics30__passes5__min_df5__max_df0.95__max_featuresNone.pickle')

# %%
import topic_modeling; reload(topic_modeling)

classy = topic_modeling.LDATopicClassifier(folder='/home/walter/Dropbox/S2DS - M&S/Data/')
text = ["sparks sparks sparks sparks sparks sparks code offer"]
text_lda_topic_distribution = classy.getLDATopicDistri(text)
print text_lda_topic_distribution
text_ms_topic_distribution = classy.getMSTopicDistri(text)
print text_ms_topic_distribution

from matplotlib.pylab import plt
# %matplotlib inline
plt.figure(num=None, figsize=(12, 4))

axis = plt.subplot(1,3,1)
classy.getLDATopicHistogram(text,axis)
axis = plt.subplot(1,3,3)
classy.getMSTopicHistogram(text,axis)

classy.print_topic_top_words()

import pyLDAvis
pyLDAvis.enable_notebook()
classy.show_pyLDAvis_plots
# Out:
# [ 0.0037037   0.0037037   0.0037037   0.0037037   0.0037037   0.78148148
#   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037
#   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037   0.11481481
#   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037
#   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037   0.0037037 ]
# [ 0.04444444  0.          0.01481481  0.0037037   0.0037037   0.11481481
#   0.0037037   0.0037037   0.01111111  0.          0.          0.0037037
#   0.0037037   0.          0.0037037   0.78518519  0.          0.0037037   0.        ]
# Topic #0:
# store collect collected pick visit need food able simply nearest
# Topic #1:
# correct mail guest incorrect amend wrong locked resend order confirmation
# Topic #2:
# param_price order discount applied place account apply bag param_number check
# Topic #3:
# stock check size product param_name item available thanks help sorry
# Topic #4:
# ...

# %%
import pyLDAvis
pyLDAvis.enable_notebook()
from pyLDAvis.sklearn import prepare
prepare(model['lda_tf'], model['dtm_tf'], model['tf_vectorizer'])
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 7      13.197987        1       1 -0.202366 -0.065385
# 0      11.373873        1       2 -0.244857 -0.000298
# 3       7.917429        1       3 -0.132379 -0.113433
# 2       7.348810        1       4 -0.206858 -0.052547
# 13      6.732280        1       5 -0.209121  0.016830
# 18      6.691454        1       6 -0.199573 -0.066136
# 14      6.261620        1       7 -0.179159 -0.113156
# 20      4.352172        1       8 -0.122709  0.036968
# 17      4.196463        1       9 -0.200991 -0.081857
# 26      3.468758        1      10 -0.090350  0.171530
# 10      3.446908        1      11 -0.021917 -0.146125
# 16      3.179896        1      12  0.028568  0.341413
# 12      3.127734        1      13 -0.137473  0.197061
# 24      2.456548        1      14 -0.056514 -0.042253
# 5       2.356660        1      15 -0.104940 -0.008036
# 6       2.307854        1      16 -0.008069 -0.026990
# ...

# %%
import pyLDAvis
pyLDAvis.enable_notebook()
from pyLDAvis.sklearn import prepare
prepare(model['lda_tf'], model['dtm_tf'], model['tf_vectorizer'])
# Out:
# /home/walter/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.py:98: DeprecationWarning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
#   def _formatters_default(self):
# /home/walter/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.py:677: DeprecationWarning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
#   def _deferred_printers_default(self):
# /home/walter/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.py:669: DeprecationWarning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
#   def _singleton_printers_default(self):
# /home/walter/anaconda2/lib/python2.7/site-packages/IPython/core/formatters.py:672: DeprecationWarning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
#   def _type_printers_default(self):
# ...

# %% [markdown]
# ### Calculate and plot topic distributions for a given chat

# %%
chat = ["sparks sparks sparks sparks sparks sparks code offer"]

lda_topic_distribution = topic_modeling.get_lda_topic_distribution(model,chat)
MS_topic_distribution  = topic_modeling.get_MS_topic_distribution(model,chat)


import numpy as np
from matplotlib.pylab import plt
# %matplotlib inline
plt.figure(num=None, figsize=(12, 4))

plt.subplot(1,2,1)
plt.hist(lda_topic_distribution,range(len(lda_topic_distribution)))
plt.xlabel('LDA Topic')
plt.ylabel('Topic probability')
plt.xticks(np.array(range(len(lda_topic_distribution)))+0.5,range(len(lda_topic_distribution)), rotation=90)

plt.subplot(1,2,2)
plt.hist(MS_topic_distribution,range(len(MS_topic_distribution)))
plt.xlabel('M&S Topic')
plt.ylabel('Topic probability')
plt.xticks(np.array(range(len(MS_topic_distribution)))+0.5,topic_modeling.get_MS_topic_labels(), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x7fc6fedbf510>,
# ...
#  <a list of 19 Text xticklabel objects>)

# %% [markdown]
# ### See top words for topic

# %%
n_top_words = 20
#def print_top_words(model, feature_names, n_top_words):
#    for topic_idx, topic in enumerate(model.components_):
#        print("Topic #%d:" % topic_idx)
#        print(" ".join([feature_names[i]
#                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
#    print()
print("\nTopics in LDA model:")
tf_feature_names = classy.model['tf_vectorizer'].get_feature_names()
topic_modeling.print_top_words(classy.model['lda_tf'], tf_feature_names, n_top_words)
# Out:
# Topics in LDA model:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-5ca5e0aaf78c> in <module>()
#       8 print("\nTopics in LDA model:")
#       9 tf_feature_names = classy.model['tf_vectorizer'].get_feature_names()
# ---> 10 topic_modeling.print_top_words(classy.model['lda_tf'], tf_feature_names, n_top_words)
#
# AttributeError: 'module' object has no attribute 'print_top_words'
