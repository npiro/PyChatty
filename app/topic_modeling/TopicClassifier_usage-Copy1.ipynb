# %% [markdown]
# ### Instantiate class with default trained model

# %%
import topic_modeling; reload(topic_modeling)
classy = topic_modeling.LDATopicClassifier(folder='C:\\Users\\Client\\Dropbox\\S2DS - M&S\\Data')

# %% [markdown]
# ### Define input text

# %%
text = ["return refunds buy pay hello money"]

# %% [markdown]
# ### calculate topic distributions

# %%
text_lda_topic_distribution = classy.getLDATopicDistri(text)
print text_lda_topic_distribution
text_ms_topic_distribution = classy.getMSTopicDistri(text)
print text_ms_topic_distribution
# Out:
# [ 0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  0.03333333
#   0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  0.71484812
#   2.48658509  0.03333333  0.03333333  0.03333333  0.03333333  0.03333333
#   0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  0.03333333
#   0.03333333  0.03333333  0.03333333  0.03333333  0.03333333  1.89856678]
# [ 1.08151479  0.          2.58658509  0.03333333  0.03333333  0.03333333
#   0.03333333  0.03333333  0.1         0.          0.          0.03333333
#   0.03333333  0.          0.03333333  1.93190012  0.          0.03333333
#   0.        ]

# %%
print(classy.get_predominant_MStopic_label(text))
# Out:
# None

# %% [markdown]
# ### plot topic distributions

# %%
from matplotlib.pylab import plt
# %matplotlib inline
plt.figure(num=None, figsize=(12, 4))

axis = plt.subplot(1,3,1)
classy.getLDATopicHistogram(text,axis)
axis = plt.subplot(1,3,3)
classy.getMSTopicHistogram(text,axis)

# %% [markdown]
# ### show visualisation in notebook

# %%
import pyLDAvis
pyLDAvis.enable_notebook()
from pyLDAvis.sklearn import prepare
prepare(classy.model['lda_tf'], classy.model['dtm_tf'], classy.model['tf_vectorizer'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-bcb78f17d091> in <module>()
# ----> 1 import pyLDAvis
#       2 pyLDAvis.enable_notebook()
#       3 from pyLDAvis.sklearn import prepare
#       4 prepare(classy.model['lda_tf'], classy.model['dtm_tf'], classy.model['tf_vectorizer'])
#
# ImportError: No module named pyLDAvis

# %% [markdown]
# ### See top words for topic

# %%
classy.print_topic_top_words()
